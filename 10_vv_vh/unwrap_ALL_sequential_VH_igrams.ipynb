# %% [markdown]
# This notebook reads in a selected region of ALL SLCs, creates interferograms with them, and outputs the igram as an ISCE-readable file for using with SNAPHU.
#
#
# This notebook: <br>
# (loops over all SLCs and does the following each time)
# 1. Reads in small window (defined in 'extract_ONE_igram...ipynb') of two vh SLCs
# 2. Creates the vh interferogram with them, filters it
# 3. Saves the full res igram as a temporary ISCE-readable file. (next time it will overwrite the igram file)
# 4. Unwraps it with SNAPHU
#
# This notebook was copied and edited to unwrap vh igrams specifically on 10-19-23.
#
# ***
# ***

# %% [markdown]
# Import the things we need.

# %%
import os,sys
import glob
import pandas as pd
import math
from osgeo import gdal
import numpy as np
from array import array
from scipy  import signal
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.stats import gaussian_kde
from scipy.ndimage import gaussian_filter

import isce
import isceobj
from contrib.Snaphu.Snaphu import Snaphu

import shutil
from imageMath import IML

# %matplotlib  widget

# %% [markdown]
# Set the working directory and define dimensions of the SLC files we'll be loading in

# %%
workdir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/'
#outputdir = str(workdir+'cropped_northern_shore_LS_for_unwrapping/')
outputdir = str(workdir+'cropped_LS_with_western_mtns/filt_unwrapped/')

# size of full res SLCs
dxIN=18000
dyIN=3600

# %% [markdown]
# If filtering first, use this window for filtering

# %%
alooks=4
rlooks=20

# %% [markdown]
# Load in the dates of the SLCs for loading them.

# %%
# load in dates
dates = [os.path.basename(x) for x in glob.glob(workdir+"SLC_vv/2*")]
dates = sorted(dates)
nd = len(dates)
print(dates)
# Out:
# ['20170510', '20170522', '20170603', '20170615', '20170627', '20170709', '20170721', '20170802', '20170814', '20170826', '20170907', '20170919', '20171013', '20171025', '20171106', '20171118', '20171130', '20171212', '20171224', '20180105', '20180117', '20180129', '20180210', '20180222', '20180306', '20180318', '20180330', '20180411', '20180423', '20180505', '20180517', '20180529', '20180610', '20180622', '20180704', '20180716', '20180728', '20180809', '20180821', '20180902', '20180914', '20180926', '20181008', '20181020', '20181101', '20181113', '20181125', '20181207', '20181219', '20181231', '20190112', '20190124', '20190205', '20190217', '20190301', '20190313', '20190325', '20190406', '20190430', '20190512', '20190524', '20190605', '20190617', '20190629', '20190711', '20190723', '20190804', '20190816', '20190822', '20190828', '20190903', '20190909', '20190915', '20190921', '20190927', '20191003', '20191009', '20191015', '20191021', '20191027', '20191102', '20191108', '20191114', '20191120', '20191126', '20191202', '20191208', '20191214', '20191220', '20191226', '20200101', '20200107', '20200113', '20200119', '20200125', '20200131', '20200206', '20200212', '20200218', '20200224', '20200301', '20200307', '20200313', '20200319', '20200325', '20200331', '20200406', '20200412', '20200418', '20200430', '20200506', '20200512', '20200518', '20200524', '20200530', '20200605', '20200611', '20200617', '20200623', '20200629', '20200705', '20200711', '20200717', '20200723', '20200729', '20200804', '20200810', '20200816', '20200822', '20200828', '20200903', '20200909', '20200915', '20200921', '20200927', '20201003', '20201009', '20201015', '20201021', '20201027', '20201102', '20201108', '20201114', '20201120', '20201126', '20201202', '20201208', '20201214', '20201220', '20201226', '20210101', '20210107', '20210113', '20210119', '20210125', '20210131', '20210206', '20210212', '20210218', '20210224', '20210302', '20210308', '20210314', '20210320', '20210326', '20210401', '20210407', '20210413', '20210419', '20210425', '20210501', '20210507', '20210513', '20210519', '20210525', '20210531', '20210606', '20210612', '20210624', '20210630', '20210706', '20210712', '20210718', '20210724', '20210730', '20210805', '20210811', '20210817', '20210823', '20210829', '20210904', '20210910', '20210916', '20210922', '20210928', '20211004', '20211010', '20211016', '20211022', '20211028', '20211103', '20211109', '20211115', '20211121', '20211127', '20211203', '20211209', '20211215', '20211221', '20211227', '20220108']

# %%
# helpful if I need to run a subset of dates 
for i in np.arange(170,nd,1):
    print(str(i)+'  '+str(dates[i]))
# Out:
# 170  20210501
# 171  20210507
# 172  20210513
# 173  20210519
# 174  20210525
# 175  20210531
# 176  20210606
# 177  20210612
# 178  20210624
# 179  20210630
# 180  20210706
# 181  20210712
# 182  20210718
# 183  20210724
# 184  20210730
# 185  20210805
# 186  20210811
# 187  20210817
# 188  20210823
# 189  20210829
# 190  20210904
# 191  20210910
# 192  20210916
# 193  20210922
# 194  20210928
# 195  20211004
# 196  20211010
# 197  20211016
# 198  20211022
# 199  20211028
# 200  20211103
# 201  20211109
# 202  20211115
# 203  20211121
# 204  20211127
# 205  20211203
# 206  20211209
# 207  20211215
# 208  20211221
# 209  20211227
# 210  20220108

# %% [markdown]
# Read in 2 SLCs for full res unwrapping with SNAPHU.

# %%
# bounding box
x1 = 17000; x2 = 14000
y1 = 1750;  y2 = 1000

# larger box with western mtns
x1 = 18000
y1 = 2100

# output file size
dxOUT = int(np.abs(x1-x2))
dyOUT = int(np.abs(y1-y2))
print('range: '+str(dxOUT))
print('azimuth: '+str(dyOUT))
print('total number of pixels: '+str(dxOUT*dyOUT))
# set the driver first, only do once.
driver=gdal.GetDriverByName('ISCE')

# loop through the dates 
for i in range(nd-1): # range(nd-1) if doing all of them at once
    # define the 2 dates. 
    date1=dates[i]
    date2=dates[i+1]
    # Read in 2 full SLCs to make interferogram 
    ds = gdal.Open(workdir+"/SLC_vh/"+date1+"/"+date1+".slc.full", gdal.GA_ReadOnly)
    slc1 = ds.GetRasterBand(1).ReadAsArray(x2,y2,dxOUT,dyOUT)
    #print('SLC 1 subsect loaded.')
    ds = gdal.Open(workdir+"/SLC_vh/"+date2+"/"+date2+".slc.full", gdal.GA_ReadOnly)
    slc2 = ds.GetRasterBand(1).ReadAsArray(x2,y2,dxOUT,dyOUT)
    #print('SLC 2 subsect loaded.')
    intTemp = (slc1*np.conj(slc2)) # NOT ANGLE

    # filter it 
    filtimager=gaussian_filter(np.real(intTemp), sigma=[alooks/4,rlooks/4])
    filtimagei=gaussian_filter(np.imag(intTemp), sigma=[alooks/4,rlooks/4])
    intTemp = filtimager+1j*filtimagei
    
    # save the file 
    igramFile = 'filtigramTemp.r4'
    colds = driver.Create(outputdir+igramFile,dxOUT,dyOUT,1,gdal.GDT_Float32)
    colds.GetRasterBand(1).WriteArray(np.angle(intTemp))
    colds=None
    
    # output a string SNAPHU output (unwrapped) file to be named. 
    outfile = outputdir+date1+'_'+date2+'_vh_filt.unw'
    #print(outfile)
    inputFilename = outputdir+igramFile
    # try using SNAPHU in the loop
    #! start_isce
    #! python /data/ocp4/LagunaSalada/testSnaphu.py '/data/ocp4/LagunaSalada/cropped_9000_1800_18000_3600/cropped_northern_shore_LS_for_unwrapping/igramTemp.r4' outfile
    #inputFilename = sys.argv[1]
    #outputFilename = sys.argv[2]
    snaphu = Snaphu()
    snaphu.setInput(inputFilename)
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211016_20211022_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211022_20211028_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 3087781
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211022_20211028_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211028_20211103_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2779089
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211028_20211103_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211103_20211109_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2685412
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211103_20211109_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 4
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211109_20211115_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2858041
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211109_20211115_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211115_20211121_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2636570
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211115_20211121_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211121_20211127_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2731324
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211121_20211127_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211127_20211203_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2512753
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211127_20211203_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211203_20211209_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 2649697
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211203_20211209_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211209_20211215_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 3720230
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211209_20211215_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211215_20211221_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 3074798
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211215_20211221_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211221_20211227_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 4483833
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211221_20211227_vh_filt.unw
# Preparing
#
# snaphu v1.4.2
# Reading wrapped phase from file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/filtigramTemp.r4
# No weight file specified.  Assuming uniform weights
# No correlation file specified.  Assuming correlation = 0.01
# Calculating deformation-mode cost parameters
# Initializing flows with MST algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Growing connected component mask
# Writing connected components to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211227_20220108_vh_filt.unw.conncomp
# Maximum flow on network: 1
# Total solution cost: 4358515
# Integrating phase
# Writing output to file /data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/20211227_20220108_vh_filt.unw

# %% [markdown]
# Load it in to test.

# %%
# test the one output I just did with fixImageXml code 
# bounding box
x1 = 17000; x2 = 14000
y1 = 1750;  y2 = 1000
# larger box with western mtns
x1 = 18000
y1 = 2100
# output file size
dxOUT = int(np.abs(x1-x2))
dyOUT = int(np.abs(y1-y2))
# load in unwrapped file and plot it to be sure SNAPHU worked. 
#f1 = gdal.Open((outputdir+'20191021_20191027_unwr.r4'), gdal.GA_ReadOnly)
i=0
date1=dates[i]
date2=dates[i+1]
#
folder = "/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/filt_unwrapped/"
f1 = gdal.Open((folder+date1+'_'+date2+'_vh_filt.unw'), gdal.GA_ReadOnly)
unwr_igram = f1.GetRasterBand(1).ReadAsArray(0,0,dxOUT,dyOUT)
f1 = None
# now plot it
fig = plt.figure(figsize=(8,5))
ax = plt.axes()
im = plt.pcolor(np.flipud(np.fliplr(unwr_igram)))
plt.colorbar(orientation='vertical',pad=0.03)
plt.set_cmap('jet')
ax.ylabel_style = {'size': 15, 'color': 'black'}
ax.xlabel_style = {'size': 15, 'color': 'black'}
plt.title('temporary igram test',fontsize=15)
plt.xlabel('range'); plt.ylabel('azimuth')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''
# this loads ALL the unwrapped igrams just saved. Not always necessary.
# make an array to hold igrams
# igramsDir is where the cropped, unwrapped igrams are 
igramsDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_northern_shore_LS_for_unwrapping/filt_unwrapped/'
# this one is to pick out the dates 
datesDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/'
# shape of unwrapped igrams
dx = 3000
dy = 750
# load in dates, make sure they are in order
dates = [os.path.basename(x) for x in glob.glob(datesDir+"SLC_vh/2*")]; dates = sorted(dates)
nd = len(dates); numIgrams = nd-1
print(str(numIgrams)+' igrams.')
igrams_unwr = np.ndarray((numIgrams,dy,dx),dtype='float')
for i in range(numIgrams):
    # define the 2 dates. 
    date1=dates[i]; date2=dates[i+1]
    # Read in the igram 
    ds = gdal.Open(igramsDir+date1+"_"+date2+"_filt.unw", gdal.GA_ReadOnly)
    #ds = gdal.Open(igramsDir+date1+"_"+date2+"_unwr.int", gdal.GA_ReadOnly)
    igrams_unwr[i] = ds.GetRasterBand(1).ReadAsArray(0,0,dx,dy)
print('filtered unwrapped igrams loaded.')
'''
