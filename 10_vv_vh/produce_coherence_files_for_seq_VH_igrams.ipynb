# %%
# import stuff
import os,sys
import glob
import pandas
from osgeo import gdal
import datetime 
from datetime import datetime
from datetime import timedelta
from dateutil import parser
import numpy as np
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
# %matplotlib  widget

# %% [markdown]
# Read in unfiltered, unwrapped igrams. Can take a few minutes.

# %%
# igramsDir is where the cropped, unwrapped igrams are 
igramsDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/unfilt_unwrapped/'
#igramsDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/unfilt_unwrapped/'

# this one is to pick out the dates 
datesDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/'
# shape of unwrapped igrams
# dx = 3000
# dy = 750

# larger area
dx = 4000
dy = 1100

# load in dates, make sure they are in order
dates = [os.path.basename(x) for x in glob.glob(datesDir+"SLC_vh/2*")]; dates = sorted(dates)
nd = len(dates); numIgrams = nd-1
# set the driver first, only do once.
driver=gdal.GetDriverByName('ISCE')
unwr_full_res = np.ndarray((numIgrams,dy,dx),dtype='float')
# loop through the dates 
for i in range(numIgrams): # numIgrams if doing all of them at once
    date1=dates[i]
    date2=dates[i+1]
    igramFile = igramsDir+date1+'_'+date2+'_vh_unfilt.unw'
    ds = gdal.Open(igramFile,gdal.GA_ReadOnly)
    unwr_full_res[i] = ds.GetRasterBand(1).ReadAsArray(0,0,dx,dy)
print('unfiltered unwrapped vh igrams loaded.')
# Out:
# unfiltered unwrapped vh igrams loaded.

# %% [markdown]
# Calculate complex coherence for each pixel for each interferogram and save them in folder: /data/ocp4/LagunaSalada/2_coherence/coh_tip_LS_all_igrams/

# %%
# calculate coherence using standard method for the point at every time

# loop through all the igrams and calculate coherence for every pixel for each one.
#coh = np.zeros((np.shape(unwr_full_res)),dtype='complex')
coh = np.ndarray((np.shape(unwr_full_res)),dtype='float')
# bounding box within full area
# larger cropped region
x1 = 18000
y1 = 2100
x2 = 14000
y2 = 1000
# dx = x1-x2 # these are already defined 
# dy = y1-y2

# area we want to average over to get coherence, same as filtering window 
alooks=4; rlooks=20 # x is range, y is azimuth 

# larger box with western mtns
# x1 = 18000 - int(rlooks/2) # because this is the edge of the SLC, I can't get coherence at the western edge pix
# y1 = 2100

# output igram size (smaller area at tip of LS)
dx2 = int(np.abs(x1-x2)); dy2 = int(np.abs(y1-y2))
# set the driver first, only do once.
driver=gdal.GetDriverByName('ISCE')

# set the folder to save these coh files to 
#saveDir = '/data/ocp4/LagunaSalada/Data_and_Figs/2_coherence/coh_tip_LS_all_igrams/'
saveDir = '/data/ocp4/LagunaSalada/Data_and_Figs/2_coherence/coh_LS_with_western_mtns_all_igrams/'

# loop through the dates 
for i in range(numIgrams): # numIgrams if doing all of them at once
    # define the 2 dates. 
    date1=dates[i]
    date2=dates[i+1]
    # Read in 2 full SLCs to make interferogram 
    ds = gdal.Open(datesDir+"SLC_vh/"+date1+"/"+date1+".slc.full", gdal.GA_ReadOnly)
    # have to load in more than just the pixels of interest to calculate coh at edge pixels 
    slc1 = ds.GetRasterBand(1).ReadAsArray(int(x2-rlooks/2),int(y2-alooks/2),int(dx2+rlooks/2),int(dy2+alooks/2))
    print(np.shape(slc1))
    ds = gdal.Open(datesDir+"SLC_vh/"+date2+"/"+date2+".slc.full", gdal.GA_ReadOnly)
    slc2 = ds.GetRasterBand(1).ReadAsArray(int(x2-rlooks/2),int(y2-alooks/2),int(dx2+rlooks/2),int(dy2+alooks/2))
    print(np.shape(slc2))
    aa = slc1*np.conj(slc1)
    bb = slc2*np.conj(slc2)
    ab = slc1*np.conj(slc2)
    print('aa,bb,ab calculated.')
    for y in np.arange(0,dy2,1): # started with this: np.arange(y2,y1,1)
        for x in np.arange(0,dx2,1): # started with this: np.arange(x2,x1,1)
            # calculate coherence using this formula: <ab*>/sqrt(<aa*><bb*>)
            # aa = np.mean(aa,axis=(0,1)); bb = np.mean(bb,axis=(0,1)); ab = np.mean(ab,axis=(0,1))# this is averaging over axes 0 and 1
            aa_temp = (np.mean(aa[int(y):int(y+alooks),int(x):int(x+rlooks)]))
            bb_temp = (np.mean(bb[int(y):int(y+alooks),int(x):int(x+rlooks)]))
            ab_temp = (np.mean(ab[int(y):int(y+alooks),int(x):int(x+rlooks)]))
            #coh[i,y,x] = ab_temp/np.sqrt(aa_temp*bb_temp) 
            coh[i,y,x] = np.abs(ab_temp/np.sqrt(aa_temp*bb_temp))
    # save the coherence plot so I can load it in easily to invert 
    save_file_name = 'coh_vh_'+str(date1)+'-'+str(date2)+'.r4'
    colds = driver.Create(saveDir+save_file_name,dx2,dy2,1,gdal.GDT_Float32)
    colds.GetRasterBand(1).WriteArray(coh[i])
    colds=None
    print('vh coh for igram '+str(i)+' done and saved.')
#print('coherence calculated for every igram for every pixel.')
# Out:
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 0 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 1 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 2 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 3 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 4 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 5 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 6 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 7 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 8 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 9 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 10 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 11 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 12 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 13 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 14 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 15 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 16 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 17 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 18 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 19 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 20 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 21 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 22 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 23 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 24 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 25 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 26 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 27 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 28 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 29 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 30 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 31 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 32 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 33 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 34 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 35 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 36 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 37 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 38 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 39 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 40 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 41 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 42 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 43 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 44 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 45 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 46 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 47 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 48 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 49 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 50 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 51 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 52 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 53 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 54 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 55 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 56 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 57 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 58 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 59 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 60 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 61 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 62 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 63 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 64 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 65 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 66 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 67 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 68 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 69 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 70 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 71 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 72 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 73 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 74 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 75 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 76 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 77 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 78 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 79 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 80 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 81 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 82 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 83 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 84 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 85 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 86 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 87 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 88 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 89 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 90 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 91 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 92 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 93 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 94 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 95 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 96 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 97 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 98 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 99 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 100 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 101 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 102 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 103 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 104 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 105 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 106 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 107 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 108 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 109 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 110 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 111 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 112 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 113 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 114 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 115 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 116 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 117 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 118 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 119 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 120 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 121 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 122 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 123 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 124 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 125 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 126 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 127 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 128 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 129 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 130 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 131 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 132 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 133 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 134 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 135 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 136 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 137 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 138 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 139 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 140 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 141 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 142 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 143 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 144 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 145 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 146 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 147 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 148 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 149 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 150 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 151 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 152 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 153 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 154 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 155 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 156 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 157 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 158 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 159 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 160 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 161 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 162 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 163 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 164 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 165 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 166 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 167 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 168 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 169 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 170 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 171 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 172 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 173 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 174 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 175 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 176 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 177 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 178 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 179 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 180 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 181 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 182 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 183 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 184 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 185 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 186 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 187 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 188 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 189 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 190 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 191 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 192 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 193 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 194 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 195 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 196 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 197 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 198 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 199 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 200 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 201 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 202 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 203 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 204 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 205 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 206 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 207 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 208 done and saved.
# (1102, 4010)
# (1102, 4010)
# aa,bb,ab calculated.
# vh coh for igram 209 done and saved.
