# %% [markdown]
# Reads in all SLCs and calculates TPC over time for each pixel then calculate average TPC for each.
# <br>
#
# written on 5-1-2023.
# ***

# %%
import os,sys
import glob
import pandas
from osgeo import gdal
import datetime 
from datetime import datetime
from datetime import timedelta
from dateutil import parser
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
from scipy.ndimage import gaussian_filter, uniform_filter
# %matplotlib  widget

# %%
workdir = '/data/ocp4/LagunaSalada/Data_and_Figs/'
cropdir = 'cropped_9000_1800_18000_3600/'

# how much to downlook?
alooks=40
rlooks=200

dates = [os.path.basename(x) for x in glob.glob(workdir+cropdir+"SLC_vv/2*")]
dates=sorted(dates)
nd=len(dates); numIgrams = nd-1; numTriplets = nd-2
print(str(nd)+' dates!') 

#larger area
dx = 4000
dy = 1100
# Out:
# 211 dates!

# %% [markdown]
# This next cell only works if I don't have a ton of variables saved on RAM.

# %%
SLCs = np.zeros((nd,dy,dx),dtype='complex')

# larger box with western mtns
x1 = 18000; x2 = 14000
y1 = 2100;  y2 = 1000

# set the driver first, only do once.
driver=gdal.GetDriverByName('ISCE')

# loop through the dates 
for i in range(nd): # numIgrams if doing all of them at once
    ds = gdal.Open(workdir+cropdir+"SLC_vv/"+dates[i]+"/"+dates[i]+".slc.full", \
                    gdal.GA_ReadOnly)
    SLCs[i] = ds.GetRasterBand(1).ReadAsArray(x2,y2,x1-x2,y1-y2)
print('SLCs loaded.')
# Out:
# SLCs loaded.

# %%
# make igrams
seq = SLCs[0:-1,:,:]*np.conj(SLCs[1:,:,:]) 
skip1 = SLCs[2:,:,:]*np.conj(SLCs[0:-2,:,:])
print('Sequential and skip1 igrams made.')
# Out:
# Sequential and skip1 igrams made.

# %% [markdown]
# Make sure I know how the Gaussian filter works by using it on a delta function.

# %%
test_array = np.zeros((1000,1000))
test_array[500,500] = 1.0
test_array_filt = gaussian_filter(test_array, sigma=[alooks/2,rlooks/2])

# plot it.
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(test_array_filt, cmap='gray',aspect='equal',interpolation='nearest')
plt.xlabel('range'); plt.ylabel('azimuth'); plt.title('Gaussian filter test') 
plt.colorbar(); 
plt.subplot(1,2,2)
plt.plot(range(1000),test_array_filt[500,:],'k.')
plt.ylim([0,0.25e-6])
plt.show()

non_zero_vals = test_array_filt[500,(np.nonzero(test_array_filt[500,:]))].flatten()
#print(np.shape(non_zero_vals))
print(non_zero_vals[0])
non_zero_x = np.nonzero(test_array_filt[500,:])[0]
#print(non_zero_x)
#print(np.shape(non_zero_x[0]))
print(non_zero_x[0])

print('Peak of Gaussian: '+str(max(non_zero_vals)))
print('Jump at edge of Gaussian: '+str(non_zero_vals[0]))
print('This is a '+str((non_zero_vals[0]/max(non_zero_vals))*100)+'% jump')
print('and it jumps down to zero (edge of filter) at the filter width away from center.')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2.669844173025905e-08
# 100
# Peak of Gaussian: 7.958693311738389e-05
# Jump at edge of Gaussian: 2.669844173025905e-08
# This is a 0.033546262790251184% jump
# and it jumps down to zero (edge of filter) at the filter width away from center.

# %%
# loop through dates and calculate TPCs spatially for each triplet 
TPC = np.ndarray((numTriplets,dy,dx),dtype='float')

# make a large array (10sigma) of zeros with one one and filter it, see how far the filter extends 
# what is the kernel
# convolving a delta function to get the filter 
# see what the "drop" is at the edge, 10% of the peak is probably too much 
# can make my own kernel and conv2 to convolve it across the data 
#

for i in range(numTriplets):
    # filter seq igram ab 
    ab_filt_r = gaussian_filter(np.real(seq[i]), sigma=[alooks/2,rlooks/2]) # 
    ab_filt_i = gaussian_filter(np.imag(seq[i]), sigma=[alooks/2,rlooks/2]) # Check older code to make sure dividing by 4 was correct for older application 
    ab_filt =   ab_filt_r + 1j*ab_filt_i
    # filter seq igram bc
    bc_filt_r = gaussian_filter(np.real(seq[i+1]), sigma=[alooks/2,rlooks/2])
    bc_filt_i = gaussian_filter(np.imag(seq[i+1]), sigma=[alooks/2,rlooks/2])
    bc_filt =   bc_filt_r + 1j*bc_filt_i
    # filter skip1 igram ac
    ac_filt_r = gaussian_filter(np.real(skip1[i]), sigma=[alooks/2,rlooks/2])
    ac_filt_i = gaussian_filter(np.imag(skip1[i]), sigma=[alooks/2,rlooks/2]) 
    ac_filt =   ac_filt_r + 1j*ac_filt_i
    # calculate the triplet 
    TPC[i] = np.angle(ab_filt * bc_filt * np.conj(ac_filt))
    print('TPCs calculated for igram triplet '+str(i))
print('All TPCs calculated.')
# Out:
# TPCs calculated for igram triplet 0
# TPCs calculated for igram triplet 1
# TPCs calculated for igram triplet 2
# TPCs calculated for igram triplet 3
# TPCs calculated for igram triplet 4
# TPCs calculated for igram triplet 5
# TPCs calculated for igram triplet 6
# TPCs calculated for igram triplet 7
# TPCs calculated for igram triplet 8
# TPCs calculated for igram triplet 9
# TPCs calculated for igram triplet 10
# TPCs calculated for igram triplet 11
# TPCs calculated for igram triplet 12
# TPCs calculated for igram triplet 13
# TPCs calculated for igram triplet 14
# TPCs calculated for igram triplet 15
# TPCs calculated for igram triplet 16
# TPCs calculated for igram triplet 17
# TPCs calculated for igram triplet 18
# TPCs calculated for igram triplet 19
# TPCs calculated for igram triplet 20
# TPCs calculated for igram triplet 21
# TPCs calculated for igram triplet 22
# TPCs calculated for igram triplet 23
# TPCs calculated for igram triplet 24
# TPCs calculated for igram triplet 25
# TPCs calculated for igram triplet 26
# TPCs calculated for igram triplet 27
# TPCs calculated for igram triplet 28
# TPCs calculated for igram triplet 29
# TPCs calculated for igram triplet 30
# TPCs calculated for igram triplet 31
# TPCs calculated for igram triplet 32
# TPCs calculated for igram triplet 33
# TPCs calculated for igram triplet 34
# TPCs calculated for igram triplet 35
# TPCs calculated for igram triplet 36
# TPCs calculated for igram triplet 37
# TPCs calculated for igram triplet 38
# TPCs calculated for igram triplet 39
# TPCs calculated for igram triplet 40
# TPCs calculated for igram triplet 41
# TPCs calculated for igram triplet 42
# TPCs calculated for igram triplet 43
# TPCs calculated for igram triplet 44
# TPCs calculated for igram triplet 45
# TPCs calculated for igram triplet 46
# TPCs calculated for igram triplet 47
# TPCs calculated for igram triplet 48
# TPCs calculated for igram triplet 49
# TPCs calculated for igram triplet 50
# TPCs calculated for igram triplet 51
# TPCs calculated for igram triplet 52
# TPCs calculated for igram triplet 53
# TPCs calculated for igram triplet 54
# TPCs calculated for igram triplet 55
# TPCs calculated for igram triplet 56
# TPCs calculated for igram triplet 57
# TPCs calculated for igram triplet 58
# TPCs calculated for igram triplet 59
# TPCs calculated for igram triplet 60
# TPCs calculated for igram triplet 61
# TPCs calculated for igram triplet 62
# TPCs calculated for igram triplet 63
# TPCs calculated for igram triplet 64
# TPCs calculated for igram triplet 65
# TPCs calculated for igram triplet 66
# TPCs calculated for igram triplet 67
# TPCs calculated for igram triplet 68
# TPCs calculated for igram triplet 69
# TPCs calculated for igram triplet 70
# TPCs calculated for igram triplet 71
# TPCs calculated for igram triplet 72
# TPCs calculated for igram triplet 73
# TPCs calculated for igram triplet 74
# TPCs calculated for igram triplet 75
# TPCs calculated for igram triplet 76
# TPCs calculated for igram triplet 77
# TPCs calculated for igram triplet 78
# TPCs calculated for igram triplet 79
# TPCs calculated for igram triplet 80
# TPCs calculated for igram triplet 81
# TPCs calculated for igram triplet 82
# TPCs calculated for igram triplet 83
# TPCs calculated for igram triplet 84
# TPCs calculated for igram triplet 85
# TPCs calculated for igram triplet 86
# TPCs calculated for igram triplet 87
# TPCs calculated for igram triplet 88
# TPCs calculated for igram triplet 89
# TPCs calculated for igram triplet 90
# TPCs calculated for igram triplet 91
# TPCs calculated for igram triplet 92
# TPCs calculated for igram triplet 93
# TPCs calculated for igram triplet 94
# TPCs calculated for igram triplet 95
# TPCs calculated for igram triplet 96
# TPCs calculated for igram triplet 97
# TPCs calculated for igram triplet 98
# TPCs calculated for igram triplet 99
# TPCs calculated for igram triplet 100
# TPCs calculated for igram triplet 101
# TPCs calculated for igram triplet 102
# TPCs calculated for igram triplet 103
# TPCs calculated for igram triplet 104
# TPCs calculated for igram triplet 105
# TPCs calculated for igram triplet 106
# TPCs calculated for igram triplet 107
# TPCs calculated for igram triplet 108
# TPCs calculated for igram triplet 109
# TPCs calculated for igram triplet 110
# TPCs calculated for igram triplet 111
# TPCs calculated for igram triplet 112
# TPCs calculated for igram triplet 113
# TPCs calculated for igram triplet 114
# TPCs calculated for igram triplet 115
# TPCs calculated for igram triplet 116
# TPCs calculated for igram triplet 117
# TPCs calculated for igram triplet 118
# TPCs calculated for igram triplet 119
# TPCs calculated for igram triplet 120
# TPCs calculated for igram triplet 121
# TPCs calculated for igram triplet 122
# TPCs calculated for igram triplet 123
# TPCs calculated for igram triplet 124
# TPCs calculated for igram triplet 125
# TPCs calculated for igram triplet 126
# TPCs calculated for igram triplet 127
# TPCs calculated for igram triplet 128
# TPCs calculated for igram triplet 129
# TPCs calculated for igram triplet 130
# TPCs calculated for igram triplet 131
# TPCs calculated for igram triplet 132
# TPCs calculated for igram triplet 133
# TPCs calculated for igram triplet 134
# TPCs calculated for igram triplet 135
# TPCs calculated for igram triplet 136
# TPCs calculated for igram triplet 137
# TPCs calculated for igram triplet 138
# TPCs calculated for igram triplet 139
# TPCs calculated for igram triplet 140
# TPCs calculated for igram triplet 141
# TPCs calculated for igram triplet 142
# TPCs calculated for igram triplet 143
# TPCs calculated for igram triplet 144
# TPCs calculated for igram triplet 145
# TPCs calculated for igram triplet 146
# TPCs calculated for igram triplet 147
# TPCs calculated for igram triplet 148
# TPCs calculated for igram triplet 149
# TPCs calculated for igram triplet 150
# TPCs calculated for igram triplet 151
# TPCs calculated for igram triplet 152
# TPCs calculated for igram triplet 153
# TPCs calculated for igram triplet 154
# TPCs calculated for igram triplet 155
# TPCs calculated for igram triplet 156
# TPCs calculated for igram triplet 157
# TPCs calculated for igram triplet 158
# TPCs calculated for igram triplet 159
# TPCs calculated for igram triplet 160
# TPCs calculated for igram triplet 161
# TPCs calculated for igram triplet 162
# TPCs calculated for igram triplet 163
# TPCs calculated for igram triplet 164
# TPCs calculated for igram triplet 165
# TPCs calculated for igram triplet 166
# TPCs calculated for igram triplet 167
# TPCs calculated for igram triplet 168
# TPCs calculated for igram triplet 169
# TPCs calculated for igram triplet 170
# TPCs calculated for igram triplet 171
# TPCs calculated for igram triplet 172
# TPCs calculated for igram triplet 173
# TPCs calculated for igram triplet 174
# TPCs calculated for igram triplet 175
# TPCs calculated for igram triplet 176
# TPCs calculated for igram triplet 177
# TPCs calculated for igram triplet 178
# TPCs calculated for igram triplet 179
# TPCs calculated for igram triplet 180
# TPCs calculated for igram triplet 181
# TPCs calculated for igram triplet 182
# TPCs calculated for igram triplet 183
# TPCs calculated for igram triplet 184
# TPCs calculated for igram triplet 185
# TPCs calculated for igram triplet 186
# TPCs calculated for igram triplet 187
# TPCs calculated for igram triplet 188
# TPCs calculated for igram triplet 189
# TPCs calculated for igram triplet 190
# TPCs calculated for igram triplet 191
# TPCs calculated for igram triplet 192
# TPCs calculated for igram triplet 193
# TPCs calculated for igram triplet 194
# TPCs calculated for igram triplet 195
# TPCs calculated for igram triplet 196
# TPCs calculated for igram triplet 197
# TPCs calculated for igram triplet 198
# TPCs calculated for igram triplet 199
# TPCs calculated for igram triplet 200
# TPCs calculated for igram triplet 201
# TPCs calculated for igram triplet 202
# TPCs calculated for igram triplet 203
# TPCs calculated for igram triplet 204
# TPCs calculated for igram triplet 205
# TPCs calculated for igram triplet 206
# TPCs calculated for igram triplet 207
# TPCs calculated for igram triplet 208
# All TPCs calculated.

# %%
# average over time 
avg_TPCs = np.mean(TPC,axis=0)
std_TPCs = np.std(TPC, axis=0)
print(np.shape(avg_TPCs))
print(np.shape(std_TPCs))
# Out:
# (1100, 4000)
# (1100, 4000)

# %%
# plot it. 
plt.figure(figsize=(6,5.5),tight_layout=True) 
plt.imshow(avg_TPCs,aspect='auto',interpolation='hermite',vmin=-0.5,vmax=0.5)
plt.colorbar(orientation='vertical',pad=0.03,label='Avg TPC (rad)'); plt.set_cmap('seismic')
plt.xlim([dx,0]); plt.ylim([dy,0])
#plt.xticks([]); plt.yticks([])
plt.title('Temporal Avg of TPC')
plt.show()
plt.figure(figsize=(6,5.5),tight_layout=True) 
plt.imshow(std_TPCs,aspect='auto',interpolation='none')
plt.colorbar(orientation='vertical',pad=0.03,label='TPC Std (rad)'); plt.set_cmap('seismic')
plt.xlim([dx,0]); plt.ylim([dy,0])
#plt.xticks([]); plt.yticks([])
plt.title('Temporal std. of TPC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7402/618104177.py in <module>
#       1 # plot it.
# ----> 2 plt.figure(figsize=(6,5.5),tight_layout=True)
#       3 plt.imshow(avg_TPCs,aspect='auto',interpolation='hermite',vmin=-0.5,vmax=0.5)
#       4 plt.colorbar(orientation='vertical',pad=0.03,label='Avg TPC (rad)'); plt.set_cmap('seismic')
#       5 plt.xlim([dx,0]); plt.ylim([dy,0])
#
# NameError: name 'plt' is not defined

# %%
# save it as an ISCE-readable file. 
driver=gdal.GetDriverByName('ISCE')
#saveDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_northern_shore_LS_for_unwrapping/masks/'
saveDir = '/data/ocp4/LagunaSalada/Data_and_Figs/cropped_9000_1800_18000_3600/cropped_LS_with_western_mtns/'

save_file_name = 'TPC_avgs.r4'
colds = driver.Create(saveDir+save_file_name,dx,dy,1,gdal.GDT_Float32)
colds.GetRasterBand(1).WriteArray(avg_TPCs)
colds=None
print('Average TPC for each pixel over time saved.')

save_file_name = 'TPC_stds.r4'
colds = driver.Create(saveDir+save_file_name,dx,dy,1,gdal.GDT_Float32)
colds.GetRasterBand(1).WriteArray(std_TPCs)
colds=None
print('Standard deviation of TPC for each pixel over time saved.')
# Out:
# Average TPC for each pixel over time saved.
# Standard deviation of TPC for each pixel over time saved.
